# %%
#Importing important libraries

import psycopg2
import pandas as pd

# %%
def create_database():
    #connect to default database
    con = psycopg2.connect("host=localhost dbname=postgres user=postgres password=root")
    con.set_session(autocommit=True)
    cur= con.cursor()
    
     #Create the real project database
    cur.execute("DROP DATABASE IF EXISTS accounts")
    cur.execute("CREATE DATABASE accounts")
    
    #close old connection and cursor
    cur.close()
    con.close()
    
    #connect to the real project database
    con = psycopg2.connect("host=localhost dbname=accounts user=postgres password=root")
    cur= con.cursor()
    
    return cur, con

# %%
def drop_table(cur, con):
    for query in drop_table_queries:
        cur.execute(query)
        con.commit()

# %%
def create_table(cur, con):
    for query in create_table_queries:
        cur.execute(query)
        con.commit()

# %%
#Reading csv file Wealth-AccountsCountry

AccountsCountry = pd.read_csv("Data/Wealth-AccountsCountry.csv")
AccountsCountry.head()
# Out:
#   Code                  Long Name         Income Group  \
# 0  ALB        Republic of Albania  Upper middle income
# 1  ARG         Argentine Republic  Upper middle income
# 2  ARM        Republic of Armenia  Upper middle income
# 3  AUS  Commonwealth of Australia          High income
# 4  AUT        Republic of Austria          High income
#
#                       Region Lending category Other groups      Currency Unit  \
# 0      Europe & Central Asia             IBRD          NaN       Albanian lek
# 1  Latin America & Caribbean             IBRD          NaN     Argentine peso
# 2      Europe & Central Asia             IBRD          NaN      Armenian dram
# 3        East Asia & Pacific              NaN          NaN  Australian dollar
# 4      Europe & Central Asia              NaN    Euro area               Euro
#
#                             Latest population census  \
# 0                                    2020 (expected)
# 1                                    2020 (expected)
# ...

# %%
AccountsCountry.columns
# Out:
# Index(['Code', 'Long Name', 'Income Group', 'Region', 'Lending category',
#        'Other groups', 'Currency Unit', 'Latest population census',
#        'Latest household survey', 'Special Notes',
#        'National accounts base year', 'National accounts reference year',
#        'System of National Accounts', 'SNA price valuation',
#        'Alternative conversion factor', 'PPP survey years',
#        'Balance of Payments Manual in use', 'External debt Reporting status',
#        'System of trade', 'Government Accounting concept',
#        'IMF data dissemination standard',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest trade data',
#        'Latest water withdrawal data', '2-alpha code', 'WB-2 code',
#        'Table Name', 'Short Name'],
#       dtype='object')

# %%
#Cleaning AccountsCountry table with only required fields

AccountsCountry = AccountsCountry [['Code', 'Short Name', 'Table Name', 'Long Name', 'Currency Unit']]
AccountsCountry.head()
# Out:
#   Code Short Name Table Name                  Long Name      Currency Unit
# 0  ALB    Albania    Albania        Republic of Albania       Albanian lek
# 1  ARG  Argentina  Argentina         Argentine Republic     Argentine peso
# 2  ARM    Armenia    Armenia        Republic of Armenia      Armenian dram
# 3  AUS  Australia  Australia  Commonwealth of Australia  Australian dollar
# 4  AUT    Austria    Austria        Republic of Austria               Euro

# %%
#Reading CSV file Wealth-AccountData.csv

AccountData = pd.read_csv("Data/Wealth-AccountData.csv")
AccountData.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999]  \
# 0      4.49E+10      4.34E+10      3.71E+10      3.88E+10      4.22E+10
# 1      14072.79      13708.99       11794.1      12399.48      13573.26
# 2      3468.858      3355.549      2868.997      3013.391      3259.893
# 3      6507.931      6353.737      5466.692      5901.072       6492.73
# ...

# %%
AccountData.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]',
#        '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]',
#        '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
#        '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
#        '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'],
#       dtype='object')

# %%
#Cleaning Wealth-AccountData table with only required fields

AccountData = AccountData.drop(['1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]',
       '1999 [YR1999]', '2001 [YR2001]', '2002 [YR2002]',
       '2003 [YR2003]', '2004 [YR2004]', '2006 [YR2006]',
       '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]',
       '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]',
       '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', 
                                '2018 [YR2018]'], axis=1)
AccountData.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 2000 [YR2000]  2005 [YR2005]  2010 [YR2010]  2014 [YR2014]
# 0      4.49E+10      4.36E+10   5.440000e+10   6.810000e+10   7.250000e+10
# 1      14072.79      14118.13   1.807230e+04   2.336286e+04   2.509002e+04
# 2      3468.858      3424.007   2.222115e+03   2.889150e+03   2.957420e+03
# ...

# %%
#Reading CSV file Wealth-AccountSeries.csv

AccountSeries = pd.read_csv("Data/Wealth-AccountSeries.csv")
AccountSeries.head()
# Out:
#              Code                                     Indicator Name  \
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition  \
# 0  Human capital is computed as the present value...
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...
#
#                                               Source          Topic  \
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# ...

# %%
AccountSeries.columns
# Out:
# Index(['Code', 'Indicator Name', 'Long definition', 'Source', 'Topic',
#        'Unit of measure', 'Periodicity', 'Reference period',
#        'Statistical concept and methodology', 'Previous Indicator Code',
#        'Previous Indicator Name'],
#       dtype='object')

# %%
#Cleaning AccountSeries table with only required fields

AccountSeries = AccountSeries [['Code', 'Topic', 'Indicator Name', 'Long definition']]
AccountSeries.head()
# Out:
#              Code          Topic  \
# 0       NW.HCA.TO  Human capital
# 1       NW.HCA.PC  Human capital
# 2  NW.HCA.FEMP.PC  Human capital
# 3  NW.HCA.MEMP.PC  Human capital
# 4  NW.HCA.FEMA.PC  Human capital
#
#                                       Indicator Name  \
# 0                  Human capital (constant 2018 US$)
# 1       Human capital per capita (constant 2018 US$)
# 2  Human capital per capita, employed female (con...
# 3  Human capital per capita, employed male (const...
# 4  Human capital per capita, female (constant 201...
#
#                                      Long definition
# 0  Human capital is computed as the present value...
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...

# %%
#let's create the database for which we wrote the UDF above

try:
    cur, con = create_database()
except psycopg2.Error as e:
    print(e)

# %%
#let's create the country table

countryTableCreate = """CREATE TABLE IF NOT EXISTS accountscountry(
country_code VARCHAR PRIMARY KEY,
short_name VARCHAR,
table_name VARCHAR,
long_name VARCHAR,
currency_unit VARCHAR)"""

# %%
try:
    cur.execute(countryTableCreate)
    con.commit()
    print("table created")
except psycopg2.Error as e:
    print(e)
# Out:
# table created

# %%
AccountData.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1995 [YR1995]', '2000 [YR2000]', '2005 [YR2005]', '2010 [YR2010]',
#        '2014 [YR2014]'],
#       dtype='object')

# %%
#let's create the data table

dataTableCreate = ("""CREATE TABLE IF NOT EXISTS accountsdata(
country_name VARCHAR,
country_code VARCHAR,
series_name VARCHAR,
series_code VARCHAR,
yr1995 numeric(20, 2),
yr2000 numeric(20, 2),
yr2005 numeric,
yr2010 numeric,
yr2014 numeric)""")

# %%
try:
    cur.execute(dataTableCreate)
    con.commit()
    print("data table created")
except psycopg2.Error as e:
    print(e)
# Out:
# data table created

# %%
#let's create the series table
seriesTableCreate = """CREATE TABLE IF NOT EXISTS accountsseries(
series_code VARCHAR,
topic VARCHAR,
indicator_name VARCHAR,
defintion VARCHAR)"""

# %%
try:
    cur.execute(seriesTableCreate)
    con.commit()
    print("data table created")
except psycopg2.Error as e:
    print(e)
# Out:
# data table created

# %%
#Let's insert values in country table
countryTableInsert = """INSERT INTO accountscountry 
(country_code, short_name, table_name, long_name, 
currency_unit) VALUES (%s, %s, %s, %s, %s)"""
#Code, ShortName, TableName, LongName, CurrencyUnit

# %%
AccountsCountry = AccountsCountry.drop_duplicates(subset = ['Code'], keep = 'first')

# %%
for i, row in AccountsCountry.iterrows():
    print (list(row))
# Out:
# ['ALB', 'Albania', 'Albania', 'Republic of Albania', 'Albanian lek']
# ['ARG', 'Argentina', 'Argentina', 'Argentine Republic', 'Argentine peso']
# ['ARM', 'Armenia', 'Armenia', 'Republic of Armenia', 'Armenian dram']
# ['AUS', 'Australia', 'Australia', 'Commonwealth of Australia', 'Australian dollar']
# ['AUT', 'Austria', 'Austria', 'Republic of Austria', 'Euro']
# ['AZE', 'Azerbaijan', 'Azerbaijan', 'Republic of Azerbaijan', 'New Azeri manat']
# ['BHR', 'Bahrain', 'Bahrain', 'Kingdom of Bahrain', 'Bahraini dinar']
# ['BGD', 'Bangladesh', 'Bangladesh', "People's Republic of Bangladesh", 'Bangladeshi taka']
# ['BLR', 'Belarus', 'Belarus', 'Republic of Belarus', 'Belarusian rubel']
# ['BEL', 'Belgium', 'Belgium', 'Kingdom of Belgium', 'Euro']
# ['BLZ', 'Belize', 'Belize', 'Belize', 'Belize dollar']
# ['BEN', 'Benin', 'Benin', 'Republic of Benin', 'West African CFA franc']
# ['BOL', 'Bolivia', 'Bolivia', 'Plurinational State of Bolivia', 'Bolivian Boliviano']
# ...

# %%
for i, row in AccountsCountry.iterrows():
    cur.execute(countryTableInsert, list(row))
    con.commit()

# %%
AccountData.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1995 [YR1995]', '2000 [YR2000]', '2005 [YR2005]', '2010 [YR2010]',
#        '2014 [YR2014]'],
#       dtype='object')

# %%
#Let's insert values in data table
dataTableInsert = """INSERT INTO accountsdata
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)"""

# %%
AccountData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7592 entries, 0 to 7591
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   7592 non-null   object
#  1   Country Code   7592 non-null   object
#  2   Series Name    7592 non-null   object
#  3   Series Code    7592 non-null   object
#  4   1995 [YR1995]  7592 non-null   object
#  5   2000 [YR2000]  7592 non-null   object
#  6   2005 [YR2005]  7592 non-null   float64
#  7   2010 [YR2010]  7592 non-null   float64
#  8   2014 [YR2014]  7592 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 533.9+ KB

# %%
columns_to_replace = ['1995 [YR1995]', '2000 [YR2000]']

for column in columns_to_replace:
    AccountData[column] = pd.to_numeric(AccountData[column], errors='coerce').fillna(0)

# %%
AccountData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7592 entries, 0 to 7591
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   7592 non-null   object
#  1   Country Code   7592 non-null   object
#  2   Series Name    7592 non-null   object
#  3   Series Code    7592 non-null   object
#  4   1995 [YR1995]  7592 non-null   float64
#  5   2000 [YR2000]  7592 non-null   float64
#  6   2005 [YR2005]  7592 non-null   float64
#  7   2010 [YR2010]  7592 non-null   float64
#  8   2014 [YR2014]  7592 non-null   float64
# dtypes: float64(5), object(4)
# memory usage: 533.9+ KB

# %%
try:
    for i, row in AccountData.iterrows():
        cur.execute(dataTableInsert, list(row))
        con.commit()
except psycopg2.Error as e:
    print("Error occurred while inserting row:")
    print(row)
    print("Error message:", e)

# %%
#Let's insert values in series table

seriesTableInsert = """INSERT INTO accountsseries
VALUES (%s, %s, %s, %s)"""

# %%
try:
    for i, row in AccountSeries.iterrows():
        cur.execute(seriesTableInsert, list(row))
        con.commit()
except psycopg2.Error as e:
    print("Error occurred while inserting row:")
    print(row)
    print("Error message:", e)

# %%
cur.close()
con.close()
